# %% [markdown]
# <a href="https://colab.research.google.com/github/mahmud-ashiq/machine_learning/blob/main/Data_Pre_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **part1: loading data set from gdrive and displaying dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/diabetes_two (1).csv')
df.head(10) #first 10 rows
# Out:
#      Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40.0   Male       No        Yes                 No      Yes         No
# 1   58.0   Male       No         No                 No      Yes         No
# 2    NaN   Male      Yes         No                 No      Yes        Yes
# 3   45.0   Male       No         No                Yes      Yes        Yes
# 4  600.0   Male      Yes        Yes                Yes      Yes        Yes
# 5   55.0   Male      Yes        Yes                 No      Yes        Yes
# 6   57.0   Male      Yes        Yes                 No      Yes        Yes
# 7   66.0   Male      Yes        Yes                Yes      Yes         No
# 8   67.0   Male      Yes        Yes                 No      Yes        Yes
# 9   70.0   Male       No        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# ...

# %%
df.tail(10) #last 10 rows
# Out:
#       Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 510  67.0    Male       No         No                 No      Yes         No
# 511  66.0    Male       No         No                 No      Yes        Yes
# 512  43.0    Male       No         No                 No       No         No
# 513  62.0  Female      Yes        Yes                Yes      Yes         No
# 514  54.0  Female      Yes        Yes                Yes      Yes        Yes
# 515  39.0  Female      Yes        Yes                Yes       No        Yes
# 516  48.0  Female      Yes        Yes                Yes      Yes        Yes
# 517  58.0  Female      Yes        Yes                Yes      Yes        Yes
# 518  32.0  Female       No         No                 No      Yes         No
# 519  42.0    Male       No         No                 No       No         No
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# ...

# %%
df[50:60] #from 50 to 59
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 50  36.0  Female      Yes        Yes                Yes       No        Yes
# 51  50.0  Female      Yes        Yes                Yes      Yes        Yes
# 52  60.0  Female       No        Yes                Yes      Yes        Yes
# 53  50.0  Female       No        Yes                Yes      Yes         No
# 54  51.0  Female       No         No                 No       No         No
# 55  38.0  Female       No         No                 No       No         No
# 56  66.0  Female      Yes        Yes                Yes      Yes        Yes
# 57  53.0  Female       No         No                 No       No        Yes
# 58  59.0  Female       No         No                 No       No         No
# 59  39.0  Female      Yes        Yes                 No      Yes        Yes
#
#    Genital thrush visual blurring Itching Irritability delayed healing  \
# ...

# %%
df['Age'].head()
# Out:
# 0     40.0
# 1     58.0
# 2      NaN
# 3     45.0
# 4    600.0
# Name: Age, dtype: float64

# %%
df.loc[(df.Age == 58 )] #print rows with condition
# Out:
#       Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 1    58.0    Male       No         No                 No      Yes         No
# 15   58.0    Male      Yes        Yes                 No      Yes        Yes
# 24   58.0    Male      Yes        Yes                Yes      Yes        Yes
# 106  58.0    Male       No        Yes                Yes      Yes        Yes
# 137  58.0    Male      Yes        Yes                Yes      Yes        Yes
# 190  58.0    Male       No        Yes                Yes      Yes        Yes
# 198  58.0  Female      Yes         No                Yes       No        Yes
# 207  58.0    Male       No         No                 No       No        Yes
# 303  58.0  Female      Yes         No                Yes       No        Yes
# 312  58.0    Male       No         No                 No       No        Yes
# 328  58.0    Male       No        Yes                 No       No         No
# ...

# %%
df.iloc[5:10] #print rows according to index numbers ___ df.iloc[x:y] or df.iloc[[1,2,3,4]]
# Out:
#     Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 5  55.0   Male      Yes        Yes                 No      Yes        Yes
# 6  57.0   Male      Yes        Yes                 No      Yes        Yes
# 7  66.0   Male      Yes        Yes                Yes      Yes         No
# 8  67.0   Male      Yes        Yes                 No      Yes        Yes
# 9  70.0   Male       No        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 5             No             Yes     Yes           No             Yes
# 6            Yes              No      No           No             Yes
# 7             No             Yes     Yes          Yes              No
# 8            Yes              No     Yes          Yes              No
# 9             No             Yes     Yes          Yes              No
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
df['Gender'].iloc[100:105]
# Out:
# 100    Female
# 101      Male
# 102    Female
# 103      Male
# 104      Male
# Name: Gender, dtype: object

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss',
#        'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring',
#        'Itching', 'Irritability', 'delayed healing', 'partial paresis',
#        'muscle stiffness', 'Alopecia', 'Obesity', 'class'],
#       dtype='object')

# %%
len(df)
# Out:
# 520

# %% [markdown]
# ## **part2: handling missing values**

# %%
   df.isnull().sum()   # missing value summation
# Out:
# Age                   1
# Gender                1
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              1
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 519 non-null    float64
#  1   Gender              519 non-null    object
#  2   Polyuria            520 non-null    object
#  3   Polydipsia          520 non-null    object
#  4   sudden weight loss  520 non-null    object
#  5   weakness            519 non-null    object
#  6   Polyphagia          520 non-null    object
#  7   Genital thrush      520 non-null    object
#  8   visual blurring     520 non-null    object
#  9   Itching             520 non-null    object
#  10  Irritability        520 non-null    object
#  11  delayed healing     520 non-null    object
#  12  partial paresis     520 non-null    object
#  13  muscle stiffness    520 non-null    object
#  14  Alopecia            520 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age
# count  519.000000
# mean    49.082852
# std     27.104027
# min     16.000000
# 25%     39.000000
# 50%     48.000000
# 75%     57.000000
# max    600.000000

# %%
df1 = df # making copies
df2  =df
df3 = df

# %%
df1.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %% [markdown]
# # **2a: Drop null value rows**

# %%
df1.dropna(subset=['Age'], inplace=True)
df1.dropna(subset=['Gender'], inplace=True)
df1.dropna(subset=['weakness'], inplace=True)

# %% [markdown]
# 2b: dont drop. put some value <br>
# for numeric null replace with mean/median/mode of cloumn<br>
# for categorical value it can be most frequent value of the colum

# %%
df2['Age'] = df2['Age'].fillna(df2['Age'].mean())  # replace by mean
#df2['Age'] = df2['Age'].fillna(df2['Age'].median())# replace by median

# %%
most_frequent_catagory = df2['Gender'].mode().iloc[0]
df2['Gender'] = df2['Gender'].fillna(most_frequent_catagory, inplace = True)

# %% [markdown]
# # **part3: handling categorial values or encoding** <br>
# 3.A: Label enconding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Gender'] = le.fit_transform(df['Gender'])
df['Polyuria'] = le.fit_transform(df['Polyuria'])
df['Polydipsia'] = le.fit_transform(df['Polydipsia'])
df['sudden weight loss'] = le.fit_transform(df['sudden weight loss'])
df['weakness'] = le.fit_transform(df['weakness'])
df['Polyphagia'] = le.fit_transform(df['Polyphagia'])
df['Genital thrush'] = le.fit_transform(df['Genital thrush'])
df['visual blurring'] = le.fit_transform(df['visual blurring'])
df['Itching'] = le.fit_transform(df['Itching'])
df['Irritability'] = le.fit_transform(df['Irritability'])
df['delayed healing'] = le.fit_transform(df['delayed healing'])
df['partial paresis'] = le.fit_transform(df['partial paresis'])
df['muscle stiffness'] = le.fit_transform(df['muscle stiffness'])
df['Alopecia'] = le.fit_transform(df['Alopecia'])
df['Obesity'] = le.fit_transform(df['Obesity'])
df['class'] = le.fit_transform(df['class'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 0 to 519
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 517 non-null    float64
#  1   Gender              517 non-null    int64
#  2   Polyuria            517 non-null    int64
#  3   Polydipsia          517 non-null    int64
#  4   sudden weight loss  517 non-null    int64
#  5   weakness            517 non-null    int64
#  6   Polyphagia          517 non-null    int64
#  7   Genital thrush      517 non-null    int64
#  8   visual blurring     517 non-null    int64
#  9   Itching             517 non-null    int64
#  10  Irritability        517 non-null    int64
#  11  delayed healing     517 non-null    int64
#  12  partial paresis     517 non-null    int64
#  13  muscle stiffness    517 non-null    int64
#  14  Alopecia            517 non-null    int64
#  15  Obesity             517 non-null    int64
# ...

# %% [markdown]
# #3B: one hot encoding

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['Gender', 'Polyuria', 'Polydipsia', 'sudden weight loss', 'weakness', 'Polyphagia', 'Genital thrush', 'visual blurring', 'Itching', 'Irritability', 'delayed healing', 'partial paresis', 'muscle stiffness', 'Alopecia', 'Obesity', 'class'])

# %%
one_hot_encoded_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 0 to 519
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   517 non-null    float64
#  1   Gender_0              517 non-null    uint8
#  2   Polyuria_0            517 non-null    uint8
#  3   Polyuria_1            517 non-null    uint8
#  4   Polydipsia_0          517 non-null    uint8
#  5   Polydipsia_1          517 non-null    uint8
#  6   sudden weight loss_0  517 non-null    uint8
#  7   sudden weight loss_1  517 non-null    uint8
#  8   weakness_0            517 non-null    uint8
#  9   weakness_1            517 non-null    uint8
#  10  Polyphagia_0          517 non-null    uint8
#  11  Polyphagia_1          517 non-null    uint8
#  12  Genital thrush_0      517 non-null    uint8
#  13  Genital thrush_1      517 non-null    uint8
#  14  visual blurring_0     517 non-null    uint8
# ...

# %% [markdown]
# # **part4: imbalance dataset issue** <br>

# %%
df['class'].unique() # what unique values
# Out:
# array([1, 0])

# %%
df['class'].nunique() # how many unique values
# Out:
# 2

# %%
value_counts = df.groupby('class').size().reset_index(name='count')
print(value_counts)
# Out:
#    class  count
# 0      0    200
# 1      1    317

# %% [markdown]
# 4a: undersampleling means reduceing the major class samples to match minor class samples

# %%
from sklearn.utils import resample
majority_class = df[df['class'] == 1]
minority_class = df[df['class'] == 0]

n_samples = len(minority_class)
majority_downsampled = resample(majority_class, replace=False, n_samples=n_samples)

balanced_df = pd.concat([minority_class,majority_downsampled])

# %%
value_counts = balanced_df.groupby('class').size().reset_index(name='count')
print(value_counts)
# Out:
#    class  count
# 0      0    200
# 1      1    200

# %% [markdown]
# 4B: oversampling (SMOTE): increasing the sample of minor class

# %%
from imblearn.over_sampling import SMOTE

# %%
X = df.drop('class', axis=1)
y= df['class']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X,y)

oversampled_df = pd.DataFrame(X_resampled, columns = X.columns)
oversampled_df['class'] = y_resampled

# %%
value_counts = oversampled_df.groupby('class').size().reset_index(name='count')
print(value_counts)
# Out:
#    class  count
# 0      0    317
# 1      1    317

# %% [markdown]
# # **part5: outlier finding and removing** <br>
# 5A: finding from figure

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(color_codes = "red")
sns.displot(data=df['Age']).set(title="Distribution of Scores", xlabel = "Scores")

# %% [markdown]
# 5B: statistical approach

# %%
df.describe()
# Out:
#               Age  Gender    Polyuria  Polydipsia  sudden weight loss  \
# count  517.000000   517.0  517.000000  517.000000          517.000000
# mean    49.112186     0.0    0.493230    0.448743            0.417795
# std     27.151937     0.0    0.500438    0.497847            0.493674
# min     16.000000     0.0    0.000000    0.000000            0.000000
# 25%     39.000000     0.0    0.000000    0.000000            0.000000
# 50%     48.000000     0.0    0.000000    0.000000            0.000000
# 75%     57.000000     0.0    1.000000    1.000000            1.000000
# max    600.000000     0.0    1.000000    1.000000            1.000000
#
#          weakness  Polyphagia  Genital thrush  visual blurring     Itching  \
# count  517.000000  517.000000      517.000000       517.000000  517.000000
# mean     0.586074    0.456480        0.220503         0.450677    0.485493
# std      0.493013    0.498585        0.414987         0.498043    0.500274
# ...

# %% [markdown]
# 5C: By finding Z-score approach [-3 to 3]

# %%
z_score = (df['Age'] - df['Age'].mean()) / df['Age'].std()

# %%
for i in z_score:
  if i<-3:
    print("You have outlier",i)
  elif i>3:
    print("You have outlier",i)
  else:
    continue
# Out:
# You have outlier 20.289079482050578

# %%
index = z_score.index[z_score == 20.289079482050578][0]
print(index)
# Out:
# 4

# %%
df['Age'][4]
# Out:
# 600.0

# %%
df['Age'][4] = df['Age'].mean()
# Out:
# <ipython-input-67-fdc4414f6837>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][4] = df['Age'].mean()

# %%
df['Age'][4]
# Out:
# 48.046638657034144

# %% [markdown]
# # **Part6: handling duplicate samples**

# %%
duplicates = df[df.duplicated(keep='first')]
duplicates
# Out:
#       Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 84   35.0       0         1           1                   1         1
# 159  38.0       0         1           1                   1         1
# 160  28.0       0         0           0                   0         0
# 161  68.0       0         1           1                   0         1
# 162  35.0       0         0           0                   0         0
# ..    ...     ...       ...         ...                 ...       ...
# 496  53.0       0         0           0                   0         1
# 497  47.0       0         0           0                   0         0
# 498  68.0       0         1           1                   0         1
# 499  64.0       0         0           0                   0         1
# 504  38.0       0         0           0                   0         0
#
#      Polyphagia  Genital thrush  visual blurring  Itching  Irritability  \
# ...

# %%
df_no_duplicates = df.drop_duplicates()

# %%
duplicates = df_no_duplicates[df_no_duplicates.duplicated(keep='first')]
duplicates
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Polyuria, Polydipsia, sudden weight loss, weakness, Polyphagia, Genital thrush, visual blurring, Itching, Irritability, delayed healing, partial paresis, muscle stiffness, Alopecia, Obesity, class]
# Index: []

# %% [markdown]
# # **Part7: feature engineering**

# %%
sns.set(font_scale=2)
plt.subplots(figsize=(20,20))
heat_plot = sns.heatmap(df_no_duplicates.corr(method='pearson'), annot=True, cmap= 'RdYlGn', annot_kws={'size':20})

plt.yticks(fontsize=35)
plt.xticks(fontsize=35)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5]),
#  [Text(0.5, 0, 'Age'),
#   Text(1.5, 0, 'Gender'),
#   Text(2.5, 0, 'Polyuria'),
#   Text(3.5, 0, 'Polydipsia'),
#   Text(4.5, 0, 'sudden weight loss'),
#   Text(5.5, 0, 'weakness'),
#   Text(6.5, 0, 'Polyphagia'),
#   Text(7.5, 0, 'Genital thrush'),
#   Text(8.5, 0, 'visual blurring'),
#   Text(9.5, 0, 'Itching'),
#   Text(10.5, 0, 'Irritability'),
#   Text(11.5, 0, 'delayed healing'),
#   Text(12.5, 0, 'partial paresis'),
#   Text(13.5, 0, 'muscle stiffness'),
#   Text(14.5, 0, 'Alopecia'),
#   Text(15.5, 0, 'Obesity'),
#   Text(16.5, 0, 'class')])

# %%
correaltions = df_no_duplicates.corr(method='pearson')
print(correaltions['class'].sort_values(ascending=False).to_string())
# Out:
# class                 1.000000
# Polyuria              0.617083
# Polydipsia            0.595928
# sudden weight loss    0.376004
# partial paresis       0.363793
# Polyphagia            0.314669
# Irritability          0.265915
# visual blurring       0.200915
# Genital thrush        0.187178
# weakness              0.140060
# muscle stiffness      0.103887
# Obesity               0.083522
# Age                   0.046284
# delayed healing       0.038164
# Itching              -0.032755
# Alopecia             -0.212693
# Gender                     NaN

# %% [markdown]
# # **part8: separating feature and target**

# %%
df_no_duplicates
# Out:
#            Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 0    40.000000       0         0           1                   0         1
# 1    58.000000       0         0           0                   0         1
# 3    45.000000       0         0           0                   1         1
# 4    48.046639       0         1           1                   1         1
# 5    55.000000       0         1           1                   0         1
# ..         ...     ...       ...         ...                 ...       ...
# 515  39.000000       0         1           1                   1         0
# 516  48.000000       0         1           1                   1         1
# 517  58.000000       0         1           1                   1         1
# 518  32.000000       0         0           0                   0         1
# 519  42.000000       0         0           0                   0         0
#
# ...

# %%
from sklearn.utils import shuffle
shuffled_df = shuffle(df_no_duplicates)

# %%
shuffled_df
# Out:
#       Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 90   45.0       0         0           0                   0         0
# 130  47.0       0         1           1                   1         1
# 87   28.0       0         0           0                   0         0
# 91   48.0       0         1           1                   1         1
# 12   35.0       0         1           0                   0         0
# ..    ...     ...       ...         ...                 ...       ...
# 213  49.0       0         0           1                   0         0
# 57   53.0       0         0           0                   0         0
# 15   58.0       0         1           1                   0         1
# 134  35.0       0         1           1                   1         1
# 246  46.0       0         0           0                   0         1
#
#      Polyphagia  Genital thrush  visual blurring  Itching  Irritability  \
# ...

# %%
rearranged_df = shuffled_df.reset_index(drop=True)

# %%
rearranged_df
# Out:
#       Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 0    45.0       0         0           0                   0         0
# 1    47.0       0         1           1                   1         1
# 2    28.0       0         0           0                   0         0
# 3    48.0       0         1           1                   1         1
# 4    35.0       0         1           0                   0         0
# ..    ...     ...       ...         ...                 ...       ...
# 243  49.0       0         0           1                   0         0
# 244  53.0       0         0           0                   0         0
# 245  58.0       0         1           1                   0         1
# 246  35.0       0         1           1                   1         1
# 247  46.0       0         0           0                   0         1
#
#      Polyphagia  Genital thrush  visual blurring  Itching  Irritability  \
# ...

# %%
X = rearranged_df.drop(columns=['class'])

# %%
X
# Out:
#       Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 0    45.0       0         0           0                   0         0
# 1    47.0       0         1           1                   1         1
# 2    28.0       0         0           0                   0         0
# 3    48.0       0         1           1                   1         1
# 4    35.0       0         1           0                   0         0
# ..    ...     ...       ...         ...                 ...       ...
# 243  49.0       0         0           1                   0         0
# 244  53.0       0         0           0                   0         0
# 245  58.0       0         1           1                   0         1
# 246  35.0       0         1           1                   1         1
# 247  46.0       0         0           0                   0         1
#
#      Polyphagia  Genital thrush  visual blurring  Itching  Irritability  \
# ...

# %%
y = rearranged_df['class']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 243    0
# 244    1
# 245    1
# 246    1
# 247    0
# Name: class, Length: 248, dtype: int64

# %% [markdown]
# # **part9: scalinf data**

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
scalar1 = MinMaxScaler()
MinMax_scaled_df = scalar1.fit_transform(X)
MinMax_scaled_df
# Out:
# array([[0.39189189, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.41891892, 0.        , 1.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.16216216, 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.56756757, 0.        , 1.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.25675676, 0.        , 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.40540541, 0.        , 0.        , ..., 0.        , 1.        ,
#         0.        ]])

# %%
scalar2 = StandardScaler()
StandardScaler_scaled_df = scalar2.fit_transform(X)
StandardScaler_scaled_df
# Out:
# array([[-0.31402789,  0.        , -1.04961656, ..., -0.79471941,
#         -0.74161985, -0.46442036],
#        [-0.15411991,  0.        ,  0.95272887, ...,  1.25830574,
#         -0.74161985, -0.46442036],
#        [-1.67324575,  0.        , -1.04961656, ...,  1.25830574,
#         -0.74161985, -0.46442036],
#        ...,
#        [ 0.725374  ,  0.        ,  0.95272887, ...,  1.25830574,
#         -0.74161985, -0.46442036],
#        [-1.1135678 ,  0.        ,  0.95272887, ..., -0.79471941,
#         -0.74161985, -0.46442036],
#        [-0.2340739 ,  0.        , -1.04961656, ..., -0.79471941,
#          1.34839972, -0.46442036]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
#split randomly 20% for testing and 80% for training
#x_train = features of training data
#y_train = target of training data

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198 entries, 177 to 21
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 198 non-null    float64
#  1   Gender              198 non-null    int64
#  2   Polyuria            198 non-null    int64
#  3   Polydipsia          198 non-null    int64
#  4   sudden weight loss  198 non-null    int64
#  5   weakness            198 non-null    int64
#  6   Polyphagia          198 non-null    int64
#  7   Genital thrush      198 non-null    int64
#  8   visual blurring     198 non-null    int64
#  9   Itching             198 non-null    int64
#  10  Irritability        198 non-null    int64
#  11  delayed healing     198 non-null    int64
#  12  partial paresis     198 non-null    int64
#  13  muscle stiffness    198 non-null    int64
#  14  Alopecia            198 non-null    int64
#  15  Obesity             198 non-null    int64
# ...

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 198 entries, 177 to 21
# Series name: class
# Non-Null Count  Dtype
# --------------  -----
# 198 non-null    int64
# dtypes: int64(1)
# memory usage: 3.1 KB

# %%
print("Train data size (features): ",len(x_train))
print("Train data size (target): ",len(y_train))

print("Test data size (features): ",len(x_test))
print("Test data size (target): ",len(y_test))
# Out:
# Train data size (features):  198
# Train data size (target):  198
# Test data size (features):  50
# Test data size (target):  50
